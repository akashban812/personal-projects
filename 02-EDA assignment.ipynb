# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Technical Assessement THD')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/Technical Assessement THD

# %%
import pandas as pd
import numpy as np
import datetime

import plotly.express as px

# %%
df=pd.read_csv('store_sales_data_processed.csv')

df['date']=pd.to_datetime(df['date'])
df=df.rename(columns={'CLUSTER':'cluster'})
df=df.sort_values(['store_nbr','date'],ascending=[True,True])
df.dtypes
# Out:
# date               datetime64[ns]
# store_nbr                   int64
# sales                     float64
# promotion_count             int64
# city                       object
# state                      object
# store_type                 object
# cluster                     int64
# holiday_type               object
# locale                     object
# locale_name                object
# description                object
# transferred                object
# year                        int64
# month                       int64
# day_of_mnth                 int64
# day_of_week                object
# daynum_of_week              int64
# mnth_name                  object
# dtype: object

# %% [markdown]
# ### Overview of strategy
#
# - In order to optimize for time, we need to look at the clusters on their own
#
# - We need to check if holidays have a positive impact
#
# - We need to look if any stores opened later than the 1st date provided
#
# -

# %%
nonzero_sales=df[['store_nbr','sales','date']].sort_values(['store_nbr','date'],ascending=[True,True])
nonzero_sales=nonzero_sales[nonzero_sales['sales']>0]
nonzero_sales_min_dt=nonzero_sales.groupby(['store_nbr'])['date'].min().reset_index().rename(columns={'date':'min_non_zero_date'})
nonzero_sales_min_dt['starting_dt']=df['date'].min()
nonzero_sales_min_dt['days_from_start']=(nonzero_sales_min_dt['min_non_zero_date']-nonzero_sales_min_dt['starting_dt'])/np.timedelta64(1, 'D')

nonzero_sales_min_dt

#we can see that some stores start showing positive values many days after the min start date.
## Thus we'll need to flag these stores as closed till the respective start dates for those with a value >1
# Out:
#     store_nbr min_non_zero_date starting_dt  days_from_start
# 0           1        2013-01-02  2013-01-01              1.0
# 1           2        2013-01-02  2013-01-01              1.0
# 2           3        2013-01-02  2013-01-01              1.0
# 3           4        2013-01-02  2013-01-01              1.0
# 4           5        2013-01-02  2013-01-01              1.0
# 5           6        2013-01-02  2013-01-01              1.0
# 6           7        2013-01-02  2013-01-01              1.0
# 7           8        2013-01-02  2013-01-01              1.0
# 8           9        2013-01-02  2013-01-01              1.0
# 9          10        2013-01-02  2013-01-01              1.0
# 10         11        2013-01-02  2013-01-01              1.0
# 11         12        2013-01-02  2013-01-01              1.0
# 12         13        2013-01-02  2013-01-01              1.0
# 13         14        2013-01-02  2013-01-01              1.0
# 14         15        2013-01-02  2013-01-01              1.0
# 15         16        2013-01-02  2013-01-01              1.0
# 16         17        2013-01-02  2013-01-01              1.0
# 17         18        2013-01-02  2013-01-01              1.0
# 18         19        2013-01-02  2013-01-01              1.0
# 19         20        2015-02-13  2013-01-01            773.0
# 20         21        2015-07-24  2013-01-01            934.0
# 21         22        2015-10-09  2013-01-01           1011.0
# 22         23        2013-01-02  2013-01-01              1.0
# 23         24        2013-01-02  2013-01-01              1.0
# 24         25        2013-01-01  2013-01-01              0.0
# 25         26        2013-01-02  2013-01-01              1.0
# 26         27        2013-01-02  2013-01-01              1.0
# 27         28        2013-01-02  2013-01-01              1.0
# 28         29        2015-03-20  2013-01-01            808.0
# 29         30        2013-01-02  2013-01-01              1.0
# 30         31        2013-01-02  2013-01-01              1.0
# 31         32        2013-01-02  2013-01-01              1.0
# 32         33        2013-01-02  2013-01-01              1.0
# 33         34        2013-01-02  2013-01-01              1.0
# 34         35        2013-01-02  2013-01-01              1.0
# 35         36        2013-05-09  2013-01-01            128.0
# 36         37        2013-01-02  2013-01-01              1.0
# 37         38        2013-01-02  2013-01-01              1.0
# 38         39        2013-01-02  2013-01-01              1.0
# 39         40        2013-01-02  2013-01-01              1.0
# 40         41        2013-01-02  2013-01-01              1.0
# 41         42        2015-08-21  2013-01-01            962.0
# 42         43        2013-01-02  2013-01-01              1.0
# 43         44        2013-01-02  2013-01-01              1.0
# 44         45        2013-01-02  2013-01-01              1.0
# 45         46        2013-01-02  2013-01-01              1.0
# 46         47        2013-01-02  2013-01-01              1.0
# 47         48        2013-01-02  2013-01-01              1.0
# 48         49        2013-01-02  2013-01-01              1.0
# 49         50        2013-01-02  2013-01-01              1.0
# 50         51        2013-01-02  2013-01-01              1.0
# 51         52        2017-04-20  2013-01-01           1570.0
# 52         53        2014-05-29  2013-01-01            513.0
# 53         54        2013-01-02  2013-01-01              1.0

# %%
##Running same check for closures

nonzero_sales=df[['store_nbr','sales','date']].sort_values(['store_nbr','date'],ascending=[True,True])
nonzero_sales=nonzero_sales[nonzero_sales['sales']>0]
nonzero_sales_max_dt=nonzero_sales.groupby(['store_nbr'])['date'].max().reset_index().rename(columns={'date':'max_non_zero_date'})
nonzero_sales_max_dt['ending_dt']=df['date'].max()
nonzero_sales_max_dt['days_from_start']=(nonzero_sales_max_dt['ending_dt']-nonzero_sales_max_dt['max_non_zero_date'])/np.timedelta64(1, 'D')
nonzero_sales_max_dt

## No action needed as all stores active till the last date
# Out:
#     store_nbr max_non_zero_date  ending_dt  days_from_start
# 0           1        2017-08-15 2017-08-15              0.0
# 1           2        2017-08-15 2017-08-15              0.0
# 2           3        2017-08-15 2017-08-15              0.0
# 3           4        2017-08-15 2017-08-15              0.0
# 4           5        2017-08-15 2017-08-15              0.0
# 5           6        2017-08-15 2017-08-15              0.0
# 6           7        2017-08-15 2017-08-15              0.0
# 7           8        2017-08-15 2017-08-15              0.0
# 8           9        2017-08-15 2017-08-15              0.0
# 9          10        2017-08-15 2017-08-15              0.0
# 10         11        2017-08-15 2017-08-15              0.0
# 11         12        2017-08-15 2017-08-15              0.0
# 12         13        2017-08-15 2017-08-15              0.0
# 13         14        2017-08-15 2017-08-15              0.0
# 14         15        2017-08-15 2017-08-15              0.0
# 15         16        2017-08-15 2017-08-15              0.0
# 16         17        2017-08-15 2017-08-15              0.0
# 17         18        2017-08-15 2017-08-15              0.0
# 18         19        2017-08-15 2017-08-15              0.0
# 19         20        2017-08-15 2017-08-15              0.0
# 20         21        2017-08-15 2017-08-15              0.0
# 21         22        2017-08-15 2017-08-15              0.0
# 22         23        2017-08-15 2017-08-15              0.0
# 23         24        2017-08-15 2017-08-15              0.0
# 24         25        2017-08-15 2017-08-15              0.0
# 25         26        2017-08-15 2017-08-15              0.0
# 26         27        2017-08-15 2017-08-15              0.0
# 27         28        2017-08-15 2017-08-15              0.0
# 28         29        2017-08-15 2017-08-15              0.0
# 29         30        2017-08-15 2017-08-15              0.0
# 30         31        2017-08-15 2017-08-15              0.0
# 31         32        2017-08-15 2017-08-15              0.0
# 32         33        2017-08-15 2017-08-15              0.0
# 33         34        2017-08-15 2017-08-15              0.0
# 34         35        2017-08-15 2017-08-15              0.0
# 35         36        2017-08-15 2017-08-15              0.0
# 36         37        2017-08-15 2017-08-15              0.0
# 37         38        2017-08-15 2017-08-15              0.0
# 38         39        2017-08-15 2017-08-15              0.0
# 39         40        2017-08-15 2017-08-15              0.0
# 40         41        2017-08-15 2017-08-15              0.0
# 41         42        2017-08-15 2017-08-15              0.0
# 42         43        2017-08-15 2017-08-15              0.0
# 43         44        2017-08-15 2017-08-15              0.0
# 44         45        2017-08-15 2017-08-15              0.0
# 45         46        2017-08-15 2017-08-15              0.0
# 46         47        2017-08-15 2017-08-15              0.0
# 47         48        2017-08-15 2017-08-15              0.0
# 48         49        2017-08-15 2017-08-15              0.0
# 49         50        2017-08-15 2017-08-15              0.0
# 50         51        2017-08-15 2017-08-15              0.0
# 51         52        2017-08-15 2017-08-15              0.0
# 52         53        2017-08-15 2017-08-15              0.0
# 53         54        2017-08-15 2017-08-15              0.0

# %%
##Treating for later opened stores
later_opened_stores=nonzero_sales_min_dt[nonzero_sales_min_dt['days_from_start']>1]


##joining to main dataset

df1=pd.merge(df,later_opened_stores,on=['store_nbr'],how='left')
df1['starting_dt']=df.date.min()
df1.loc[(df1['min_non_zero_date'].isnull()),'min_non_zero_date']=df1['starting_dt']
df1['active']='Y'
df1.loc[(df1['date']<df1['min_non_zero_date']),'active']='N'
df1.reset_index(drop=True,inplace=True)

# %%
store_type_dummies=pd.get_dummies(df1.store_type,prefix='st',drop_first=True)
store_type_dummies
df1=pd.concat([df1,store_type_dummies],axis=1)
df1
# Out:
#             date  store_nbr         sales  promotion_count       city  \
# 0     2013-01-01          1      0.000000                0      Quito
# 1     2013-01-02          1   7417.148000                0      Quito
# 2     2013-01-03          1   5873.244001                0      Quito
# 3     2013-01-04          1   5919.879001                0      Quito
# 4     2013-01-05          1   6318.785010                0      Quito
# ...          ...        ...           ...              ...        ...
# 90931 2017-08-11         54   8513.834000              166  El Carmen
# 90932 2017-08-12         54   9139.678002              138  El Carmen
# 90933 2017-08-13         54  14246.827996              173  El Carmen
# 90934 2017-08-14         54  11882.994000              126  El Carmen
# 90935 2017-08-15         54  12666.858000              204  El Carmen
#
#            state store_type  cluster holiday_type    locale  ...  \
# 0      Pichincha          D       13      Holiday  National  ...
# 1      Pichincha          D       13          NaN       NaN  ...
# 2      Pichincha          D       13          NaN       NaN  ...
# 3      Pichincha          D       13          NaN       NaN  ...
# 4      Pichincha          D       13     Work Day  National  ...
# ...          ...        ...      ...          ...       ...  ...
# 90931     Manabi          C        3     Transfer  National  ...
# 90932     Manabi          C        3          NaN       NaN  ...
# 90933     Manabi          C        3          NaN       NaN  ...
# 90934     Manabi          C        3          NaN       NaN  ...
# 90935     Manabi          C        3      Holiday     Local  ...
#
#       daynum_of_week mnth_name min_non_zero_date  starting_dt  \
# 0                  2       Jan        2013-01-01   2013-01-01
# 1                  3       Jan        2013-01-01   2013-01-01
# 2                  4       Jan        2013-01-01   2013-01-01
# 3                  5       Jan        2013-01-01   2013-01-01
# 4                  6       Jan        2013-01-01   2013-01-01
# ...              ...       ...               ...          ...
# 90931              5       Aug        2013-01-01   2013-01-01
# 90932              6       Aug        2013-01-01   2013-01-01
# 90933              0       Aug        2013-01-01   2013-01-01
# 90934              1       Aug        2013-01-01   2013-01-01
# 90935              2       Aug        2013-01-01   2013-01-01
#
#        days_from_start  active st_B  st_C st_D st_E
# 0                  NaN       Y    0     0    1    0
# 1                  NaN       Y    0     0    1    0
# 2                  NaN       Y    0     0    1    0
# 3                  NaN       Y    0     0    1    0
# 4                  NaN       Y    0     0    1    0
# ...                ...     ...  ...   ...  ...  ...
# 90931              NaN       Y    0     1    0    0
# 90932              NaN       Y    0     1    0    0
# 90933              NaN       Y    0     1    0    0
# 90934              NaN       Y    0     1    0    0
# 90935              NaN       Y    0     1    0    0
#
# [90936 rows x 27 columns]

# %%
##getting count of stores by cluster
cluster_cnt=df1.groupby(['cluster'])['store_nbr'].nunique().reset_index().rename(columns={'store_nbr':'store_cnt'})
cluster_cnt
# Out:
#     cluster  store_cnt
# 0         1          3
# 1         2          2
# 2         3          7
# 3         4          3
# 4         5          1
# 5         6          6
# 6         7          2
# 7         8          3
# 8         9          2
# 9        10          6
# 10       11          3
# 11       12          1
# 12       13          4
# 13       14          4
# 14       15          5
# 15       16          1
# 16       17          1

# %%
##Trying for 1 cluster





##Try to fit for cluster 6

cl6=df1[df1['cluster']==17]
cl6=cl6[cl6['active']=='Y']
cl6.reset_index(drop=True,inplace=True)

cl6
# Out:
#            date  store_nbr         sales  promotion_count       city   state  \
# 0    2013-01-01         51      0.000000                0  Guayaquil  Guayas
# 1    2013-01-02         51  15134.490990                0  Guayaquil  Guayas
# 2    2013-01-03         51  11170.057015                0  Guayaquil  Guayas
# 3    2013-01-04         51  12452.326000                0  Guayaquil  Guayas
# 4    2013-01-05         51  15046.247000                0  Guayaquil  Guayas
# ...         ...        ...           ...              ...        ...     ...
# 1679 2017-08-11         51  26070.018000              312  Guayaquil  Guayas
# 1680 2017-08-12         51  19532.964000              139  Guayaquil  Guayas
# 1681 2017-08-13         51  25713.284030              145  Guayaquil  Guayas
# 1682 2017-08-14         51  18932.967000              132  Guayaquil  Guayas
# 1683 2017-08-15         51  20154.559000              127  Guayaquil  Guayas
#
#      store_type  cluster holiday_type    locale  ... daynum_of_week mnth_name  \
# 0             A       17      Holiday  National  ...              2       Jan
# 1             A       17          NaN       NaN  ...              3       Jan
# 2             A       17          NaN       NaN  ...              4       Jan
# 3             A       17          NaN       NaN  ...              5       Jan
# 4             A       17     Work Day  National  ...              6       Jan
# ...         ...      ...          ...       ...  ...            ...       ...
# 1679          A       17     Transfer  National  ...              5       Aug
# 1680          A       17          NaN       NaN  ...              6       Aug
# 1681          A       17          NaN       NaN  ...              0       Aug
# 1682          A       17          NaN       NaN  ...              1       Aug
# 1683          A       17      Holiday     Local  ...              2       Aug
#
#      min_non_zero_date  starting_dt  days_from_start  active st_B  st_C st_D  \
# 0           2013-01-01   2013-01-01              NaN       Y    0     0    0
# 1           2013-01-01   2013-01-01              NaN       Y    0     0    0
# 2           2013-01-01   2013-01-01              NaN       Y    0     0    0
# 3           2013-01-01   2013-01-01              NaN       Y    0     0    0
# 4           2013-01-01   2013-01-01              NaN       Y    0     0    0
# ...                ...          ...              ...     ...  ...   ...  ...
# 1679        2013-01-01   2013-01-01              NaN       Y    0     0    0
# 1680        2013-01-01   2013-01-01              NaN       Y    0     0    0
# 1681        2013-01-01   2013-01-01              NaN       Y    0     0    0
# 1682        2013-01-01   2013-01-01              NaN       Y    0     0    0
# 1683        2013-01-01   2013-01-01              NaN       Y    0     0    0
#
#      st_E
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1679    0
# 1680    0
# 1681    0
# 1682    0
# 1683    0
#
# [1684 rows x 27 columns]

# %%
timevar=cl6[['year','month','daynum_of_week']].drop_duplicates(keep='first').reset_index(drop=True)

time_yr=pd.get_dummies(timevar.year,prefix='yr',drop_first=True)

timevar=pd.concat([timevar,time_yr],axis=1)

timevar['sin_mnth']=np.sin(np.deg2rad(df.month))

timevar['cos_mnth']=np.cos(np.deg2rad(df.month))

timevar['sin_dow']=np.sin(np.deg2rad(df.daynum_of_week))

timevar['cos_dow']=np.cos(np.deg2rad(df.daynum_of_week))

cl6=pd.merge(cl6,timevar,on=['year','month','daynum_of_week'],how='inner')
cl6.reset_index(drop=True,inplace=True)

# %%
cl6
# Out:
#            date  store_nbr         sales  promotion_count       city   state  \
# 0    2013-01-01         51      0.000000                0  Guayaquil  Guayas
# 1    2013-01-08         51  10525.460009                0  Guayaquil  Guayas
# 2    2013-01-15         51  10648.973980                0  Guayaquil  Guayas
# 3    2013-01-22         51   9573.298010                0  Guayaquil  Guayas
# 4    2013-01-29         51   8741.145000                0  Guayaquil  Guayas
# ...         ...        ...           ...              ...        ...     ...
# 1679 2017-08-12         51  19532.964000              139  Guayaquil  Guayas
# 1680 2017-08-06         51  29140.969000              134  Guayaquil  Guayas
# 1681 2017-08-13         51  25713.284030              145  Guayaquil  Guayas
# 1682 2017-08-07         51  21202.605000              131  Guayaquil  Guayas
# 1683 2017-08-14         51  18932.967000              132  Guayaquil  Guayas
#
#      store_type  cluster holiday_type    locale  ... yr_2014 yr_2015 yr_2016  \
# 0             A       17      Holiday  National  ...       0       0       0
# 1             A       17          NaN       NaN  ...       0       0       0
# 2             A       17          NaN       NaN  ...       0       0       0
# 3             A       17          NaN       NaN  ...       0       0       0
# 4             A       17          NaN       NaN  ...       0       0       0
# ...         ...      ...          ...       ...  ...     ...     ...     ...
# 1679          A       17          NaN       NaN  ...       0       0       0
# 1680          A       17          NaN       NaN  ...       0       0       0
# 1681          A       17          NaN       NaN  ...       0       0       0
# 1682          A       17          NaN       NaN  ...       0       0       0
# 1683          A       17          NaN       NaN  ...       0       0       0
#
#       yr_2017  sin_mnth  cos_mnth   sin_dow   cos_dow outliers    scores
# 0           0  0.017452  0.999848  0.034899  0.999391        Y -0.027615
# 1           0  0.017452  0.999848  0.034899  0.999391        N  0.088390
# 2           0  0.017452  0.999848  0.034899  0.999391        N  0.089019
# 3           0  0.017452  0.999848  0.034899  0.999391        N  0.080488
# 4           0  0.017452  0.999848  0.034899  0.999391        N  0.065544
# ...       ...       ...       ...       ...       ...      ...       ...
# 1679        1  0.017452  0.999848  0.000000  1.000000        N  0.011266
# 1680        1  0.017452  0.999848  0.017452  0.999848        N  0.005663
# 1681        1  0.017452  0.999848  0.017452  0.999848        N  0.024792
# 1682        1  0.017452  0.999848  0.034899  0.999391        N  0.050172
# 1683        1  0.017452  0.999848  0.034899  0.999391        N  0.051771
#
# [1684 rows x 37 columns]

# %%
model_data=cl6[['sales','promotion_count','month','store_nbr','sin_mnth','cos_mnth','sin_dow','cos_dow','st_B','st_C','st_D','st_E']]

from sklearn.ensemble import IsolationForest
if_model=IsolationForest(n_estimators=200,max_samples=0.9,max_features=12,contamination=0.05,random_state=42)
if_model.fit(model_data)

cl6['outliers']=pd.Series(if_model.predict(model_data)).apply(lambda x: 'Y' if (x==-1) else 'N' )
score=if_model.decision_function(model_data)
cl6['scores']=score
fig=px.scatter(cl6, x="date", y="sales", color='outliers', facet_row="store_nbr")

fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning:
#
# X does not have valid feature names, but IsolationForest was fitted with feature names
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e78ab43d-6cec-4b84-9b53-f62e574bcc16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e78ab43d-6cec-4b84-9b53-f62e574bcc16")) {                    Plotly.newPlot(                        "e78ab43d-6cec-4b84-9b53-f62e574bcc16",                        [{"hovertemplate":"outliers=Y<br>store_nbr=51<br>date=%{x}<br>sales=%{y}<extra></extra>","legendgroup":"Y","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Y","showlegend":true,"x":["2013-01-01T00:00:00","2013-03-12T00:00:00","2014-01-01T00:00:00","2014-01-05T00:00:00","2014-12-19T00:00:00","2014-12-26T00:00:00","2015-01-01T00:00:00","2015-07-05T00:00:00","2015-12-23T00:00:00","2015-12-19T00:00:00","2015-12-26T00:00:00","2015-12-20T00:00:00","2015-12-21T00:00:00","2016-01-01T00:00:00","2016-01-20T00:00:00","2016-02-05T00:00:00","2016-02-12T00:00:00","2016-04-17T00:00:00","2016-04-18T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-10-26T00:00:00","2016-11-04T00:00:00","2016-11-05T00:00:00","2016-11-13T00:00:00","2016-12-23T00:00:00","2016-12-30T00:00:00","2016-12-11T00:00:00","2016-12-18T00:00:00","2016-12-19T00:00:00","2016-12-06T00:00:00","2016-12-13T00:00:00","2016-12-20T00:00:00","2016-12-27T00:00:00","2016-12-07T00:00:00","2016-12-14T00:00:00","2016-12-21T00:00:00","2016-12-28T00:00:00","2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-24T00:00:00","2017-01-04T00:00:00","2017-01-11T00:00:00","2017-01-18T00:00:00","2017-01-25T00:00:00","2017-01-05T00:00:00","2017-01-12T00:00:00","2017-01-19T00:00:00","2017-01-26T00:00:00","2017-01-06T00:00:00","2017-01-13T00:00:00","2017-01-20T00:00:00","2017-01-27T00:00:00","2017-02-05T00:00:00","2017-02-12T00:00:00","2017-02-27T00:00:00","2017-04-01T00:00:00","2017-04-30T00:00:00","2017-04-24T00:00:00","2017-04-04T00:00:00","2017-04-11T00:00:00","2017-04-25T00:00:00","2017-04-19T00:00:00","2017-04-26T00:00:00","2017-04-06T00:00:00","2017-05-01T00:00:00","2017-05-03T00:00:00","2017-05-10T00:00:00","2017-05-17T00:00:00","2017-05-19T00:00:00","2017-05-13T00:00:00","2017-06-04T00:00:00","2017-06-11T00:00:00","2017-06-14T00:00:00","2017-06-21T00:00:00","2017-07-05T00:00:00","2017-07-12T00:00:00","2017-07-19T00:00:00","2017-07-26T00:00:00","2017-08-02T00:00:00","2017-08-09T00:00:00","2017-08-04T00:00:00","2017-08-11T00:00:00","2017-08-05T00:00:00"],"xaxis":"x","y":[0.0,6446.291,0.0,28574.51199,29647.92601,27870.425,0.0,38403.635,39229.0829,35835.543999999994,24874.663,33749.42099,40277.98997,0.0,28041.326,25403.746995,22649.862000000005,41598.28109999999,41745.40895600001,35621.04,36211.78903,22928.501,19568.456,18152.28,33394.779299999995,40920.884,37800.145,32296.91,36331.785,29431.756000000005,19205.800996,18563.935,29411.173998,21624.076,28214.428000000004,33909.893002,39315.81196000001,29393.692000000003,0.0,27594.1,29489.021,18118.612996,33134.5135,26080.624,28931.799,25752.924000000003,22408.04,16952.410999999996,17272.369981000003,17644.957000000002,27559.935,29044.844,26266.043,25648.79,30048.09,26923.964,16296.978,35796.22901,23193.823,20141.248,20336.68903,17351.208000000002,19822.312995,25064.297999999995,27964.018,14284.85898,32693.820000000003,27963.143,26592.813980000003,28664.33003,23985.34402,34869.95601,34750.384,34311.871,25822.523999,24892.254,27781.381996,26194.840002,26832.680000000004,25735.891,28939.482000000004,25054.913000000004,26565.046,26070.018,27732.397],"yaxis":"y","type":"scattergl"},{"hovertemplate":"outliers=N<br>store_nbr=51<br>date=%{x}<br>sales=%{y}<extra></extra>","legendgroup":"N","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"N","showlegend":true,"x":["2013-01-08T00:00:00","2013-01-15T00:00:00","2013-01-22T00:00:00","2013-01-29T00:00:0 ...

# %%
fig_hist = px.histogram(cl6, x="scores", nbins=50)
fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48923de2-0fea-47c5-84c2-f3e6b3ac8779" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48923de2-0fea-47c5-84c2-f3e6b3ac8779")) {                    Plotly.newPlot(                        "48923de2-0fea-47c5-84c2-f3e6b3ac8779",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"scores=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[-0.024966324761406256,0.0802532526841695,0.08252659133792417,0.0690108324922643,0.047317878562460836,0.0657614147200748,0.0756116948344529,0.07665227510204031,0.07389281179369434,0.07806628548596195,0.06366092560501757,0.06065122135234402,0.05990654347393681,0.05432191403612252,0.05036256868815625,0.045570884630771746,0.055926831931127796,0.05277228173054205,0.054162750794668924,0.017973527869280193,0.01955462147109366,0.02392858459036795,0.02529185662014488,0.030651617407792875,0.044570688471926356,0.050060140601331904,0.05175241669544184,0.0593766986652946,0.06596992337218638,0.06437154167629283,0.06119301814242856,0.08037297271693472,0.08032412021242868,0.08562604726178574,0.08391680225276277,0.08446927181033093,0.08631344099564342,0.07598858851602003,0.0866347747378245,0.07551684940608089,0.03936678038009633,0.08101484373926199,0.08800767163613632,0.07073024725507543,0.003121269836070417,0.06705881052504181,0.06920608865051164,0.04270760831480214,0.04115404884753515,0.03704614957274055,0.03899778132158671,0.06812384196835092,0.062322503887161707,0.06793931743600734,0.06036400723431634,0.07330197012474221,0.06535788016997784,0.04181761554168939,0.06588680953833964,0.09294782742763286,0.09781339586320786,0.0940560017492667,0.09269081541843938,0.0965149837965531,0.09788453003003056,0.09784654991003455,0.08380945922438537,0.09869175811776243,0.08678770646322415,0.07513107804699443,0.0969275073680872,0.09863268087462851,0.09700697274671888,0.09041652628598706,0.07473483216939936,0.07480676338227032,0.07579006533747756,0.07577427040085166,0.05072668699241467,-0.017070452933280467,0.04590410474604245,0.04659991204262803,0.07735512259056132,0.0729828857030902,0.0779597955484142,0.07606288445186743,0.05660072003017502,0.03426627573698271,0.054488207190556914,0.08176216919761115,0.09403209786224437,0.09748698670230693,0.09895662107286202,0.09748698670230693,0.09246853910451636,0.09549345335414677,0.08975468870184528,0.09145553705443726,0.09216814849361804,0.096354543126344,0.0985099799634312,0.0934742802933144,0.09970338148397812,0.09104163709193125,0.07321201824797646,0.049211846926745406,0.07271482669517476,0.07103733223445718,0.05614371560171472,0.052551610001521865,0.05596756106397982,0.05717056395065523,0.07429054000739743,0.07162138298195492,0.07254054276780814,0.07326463519500026,0.08365270130307251,0.08197150280892046,0.0813783595098595,0.08538662244356277,0.08200441146320636,0.09652178136395406,0.0965606212901956,0.09661387105190106,0.09416388472321785,0.09552868272433318,0.08926569955322511,0.09666880439801917,0.08823569898655664,0.0896196246381063,0.09969542337897802,0.09858212878854272,0.09686157798994621,0.08943055697948532,0.09625001960117285,0.06859878821452164,0.05946668088744694,0.06517901200980242,0.0741689985274005,0.040694036549703494,0.06685809724915132,0.04349004597772199,0.056441170550222464,0.08123720942068685,0.08042649319782796,0.07432950010678246,0.07501110695948726,0.07006817240125413,0.08028262842521827,0.07248118138942145,0.07733984918523562,0.09196275184478103,0.08953124560056352,0.08059204672635789,0.08891000242862451,0.08941626533574742,0.08386469182230999,0.09599639694688566,0.09964184169389362,0.0959722705276011,0.090 ...

# %%
cl6.query('outliers=="Y"')
# Out:
#            date  store_nbr         sales  promotion_count       city   state  \
# 0    2013-01-01         51      0.000000                0  Guayaquil  Guayas
# 79   2013-03-12         51   6446.291000                0  Guayaquil  Guayas
# 364  2014-01-01         51      0.000000                0  Guayaquil  Guayas
# 383  2014-01-05         51  28574.511990                0  Guayaquil  Guayas
# 706  2014-12-23         51  36616.891000               40  Guayaquil  Guayas
# ...         ...        ...           ...              ...        ...     ...
# 1658 2017-07-12         51  26194.840002              472  Guayaquil  Guayas
# 1659 2017-07-19         51  26832.680000              437  Guayaquil  Guayas
# 1675 2017-08-10         51  15364.387000              101  Guayaquil  Guayas
# 1676 2017-08-04         51  26565.046000              303  Guayaquil  Guayas
# 1677 2017-08-11         51  26070.018000              312  Guayaquil  Guayas
#
#      store_type  cluster holiday_type    locale  ... yr_2014 yr_2015 yr_2016  \
# 0             A       17      Holiday  National  ...       0       0       0
# 79            A       17          NaN       NaN  ...       0       0       0
# 364           A       17      Holiday  National  ...       1       0       0
# 383           A       17          NaN       NaN  ...       1       0       0
# 706           A       17   Additional  National  ...       1       0       0
# ...         ...      ...          ...       ...  ...     ...     ...     ...
# 1658          A       17          NaN       NaN  ...       0       0       0
# 1659          A       17          NaN       NaN  ...       0       0       0
# 1675          A       17      Holiday  National  ...       0       0       0
# 1676          A       17          NaN       NaN  ...       0       0       0
# 1677          A       17     Transfer  National  ...       0       0       0
#
#       yr_2017  sin_mnth  cos_mnth   sin_dow   cos_dow outliers    scores
# 0           0  0.017452  0.999848  0.034899  0.999391        Y -0.024966
# 79          0  0.017452  0.999848  0.104528  0.994522        Y -0.017070
# 364         0  0.052336  0.998630  0.034899  0.999391        Y -0.033158
# 383         0  0.052336  0.998630  0.104528  0.994522        Y -0.011258
# 706         0  0.104528  0.994522  0.052336  0.998630        Y -0.016475
# ...       ...       ...       ...       ...       ...      ...       ...
# 1658        1  0.017452  0.999848  0.000000  1.000000        Y -0.010347
# 1659        1  0.017452  0.999848  0.000000  1.000000        Y -0.003115
# 1675        1  0.017452  0.999848  0.087156  0.996195        Y -0.001621
# 1676        1  0.017452  0.999848  0.104528  0.994522        Y -0.025065
# 1677        1  0.017452  0.999848  0.104528  0.994522        Y -0.027935
#
# [85 rows x 37 columns]
